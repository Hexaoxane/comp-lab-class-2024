# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 创建一个三维图形对象
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 创建帧数数组
frames_300 = np.arange(len(phi_angles_300))
frames_400 = np.arange(len(phi_angles_400))
frames_600 = np.arange(len(phi_angles_600))

# 添加 300K 的数据
ax.plot(frames_300, 300 * np.ones_like(phi_angles_300), phi_angles_300.flatten(), label='Phi (300K)', alpha=0.8)
ax.plot(frames_300, 300 * np.ones_like(psi_angles_300), psi_angles_300.flatten(), label='Psi (300K)', linestyle='dashed', alpha=0.8)

# 添加 400K 的数据
ax.plot(frames_400, 400 * np.ones_like(phi_angles_400), phi_angles_400.flatten(), label='Phi (400K)', alpha=0.8)
ax.plot(frames_400, 400 * np.ones_like(psi_angles_400), psi_angles_400.flatten(), label='Psi (400K)', linestyle='dashed', alpha=0.8)

# 添加 600K 的数据
ax.plot(frames_600, 600 * np.ones_like(phi_angles_600), phi_angles_600.flatten(), label='Phi (600K)', alpha=0.8)
ax.plot(frames_600, 600 * np.ones_like(psi_angles_600), psi_angles_600.flatten(), label='Psi (600K)', linestyle='dashed', alpha=0.8)

# 设置轴标签
ax.set_xlabel('Frame')
ax.set_ylabel('Temperature (K)')
ax.set_zlabel('Dihedral Angle (radians)')
ax.set_title('3D Plot of Phi and Psi Angles at Different Temperatures')

# 显示图例
ax.legend()

plt.show()
