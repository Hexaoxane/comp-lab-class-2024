# %%
import numpy as np
import psi4
import matplotlib.pyplot as plt

# 设置内存
psi4.set_memory('500 MB')

# 定义距离范围并增加点
Rvals = np.linspace(3.5, 5.0, 15)  # 缩小距离范围，生成 15 个点
energies = []

# 计算每个距离的能量并保存到文件
with open("psi4_results.txt", "w") as f:
    f.write("Distance(Å) Energy(Hartree)\n")
    for R in Rvals:
        # 定义氩分子的几何结构
        ar2 = psi4.geometry(f"""
        0 1
        Ar
        --
        Ar 1 {R}
        """)
        
        # 计算能量
        try:
            energy = psi4.energy('ccsd(t)/cc-pvdz', molecule=ar2)
            energies.append(energy)
            f.write(f"{R:.2f} {energy}\n")  # 保存距离和能量到文件
            print(f"Distance: {R} Å, Energy: {energy} Hartree")
        except Exception as e:
            print(f"Energy calculation failed at distance {R} Å with error: {e}")
            energies.append(np.nan)  # 若计算失败，存储 NaN 以占位

# 读取文件中的数据
data = np.loadtxt("psi4_results.txt", skiprows=1)
Rvals = data[:, 0]
energies = data[:, 1]

# 将能量从 Hartree 转换为 kcal/mol，并输出转换后的数据
energies = energies * psi4.constants.hartree2kcalmol
print("Converted Energies (kcal/mol):", energies)

# 绘制计算点的折线图
plt.figure(figsize=(8, 5))
plt.plot(Rvals, energies, '-o', label="Calculated Energies")
plt.xlabel("Distance (Å)")
plt.ylabel("Energy (kcal/mol)")
plt.title("Calculated Energies for Ar-Ar Interaction")
plt.legend()
# 保存图片至指定文件夹
plt.savefig("/scratch/hz3883/Week10-IntroElectronicStructure/Ar_Ar_Calculated_Energies.png")
print("Plot saved successfully.")

plt.show()
# Out:
#   Memory set to 476.837 MiB by Python driver.
#
# Scratch directory: /tmp/
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Thu Nov  7 15:45:50 2024
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry AR         line   718 file /ext3/miniconda3/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          AR           0.000000000000     0.000000000000    -1.750000000000    39.962383123700
#          AR           0.000000000000     0.000000000000     1.750000000000    39.962383123700
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.06887  C =      0.06887 [cm^-1]
#   Rotational constants: A = ************  B =   2064.71317  C =   2064.71317 [MHz]
#   Nuclear repulsion =   48.986690359165706
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 36
#   Nalpha       = 18
#   Nbeta        = 18
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 16
#     Number of basis functions: 36
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 444222 doubles for integral storage.
#   We computed 8414 shell quartets total.
#   Whereas there are 9316 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              357
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1.0776133932E-01.
#   Reciprocal condition number of the overlap matrix is 6.4907846686E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58492467671863   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59842721774999   -1.35025e-02   2.04106e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59887230632285   -4.45089e-04   5.12417e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59889763542856   -2.53291e-05   8.71174e-06 DIIS
#    @RHF iter   4: -1053.59889764335458   -7.92602e-09   1.31985e-06 DIIS
#    @RHF iter   5: -1053.59889764375066   -3.96085e-10   8.60782e-08 DIIS
#    @RHF iter   6: -1053.59889764375180   -1.13687e-12   1.63414e-08 DIIS
#    @RHF iter   7: -1053.59889764375203   -2.27374e-13   2.40865e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118.605757     1Ag  -118.605757     2B1u  -12.317365
#        2Ag   -12.317355     3B1u   -9.565893     3Ag    -9.565889
#        1B2g   -9.565885     1B3g   -9.565885     1B3u   -9.565884
#        1B2u   -9.565884     4Ag    -1.275743     4B1u   -1.272811
#        5Ag    -0.600002     2B2u   -0.589601     2B3u   -0.589601
#        2B3g   -0.586129     2B2g   -0.586129     5B1u   -0.575908
#
#     Virtual:
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.291688499582469
#       * MP2 total energy                      = -1053.890586143336577
#
#     Opposite-spin CCSD correlation energy     =   -0.234863537437900
#     Same-spin CCSD correlation energy         =   -0.078227420716023
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.313090958153923
#       * CCSD total energy                     = -1053.911988601907979
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   48.986690359165706
#     SCF energy          (wfn)                = -1053.598897643752025
#     Reference energy    (file100)            = -1053.598897643754071
#     CCSD energy         (file100)            =   -0.313090958153923
#     Total CCSD energy   (file100)            = -1053.911988601907979
#
#     Number of ijk index combinations:             1140
#     Memory available in words               :        62500000
#     Approx. words needed per explicit thread:             256
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002626247522957
#       * CCSD(T) total energy                  = -1053.914614849431018
#
# Distance: 3.5 Å, Energy: -1053.914614849431 Hartree
#
# Scratch directory: /tmp/
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Thu Nov  7 15:45:53 2024
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry AR         line   718 file /ext3/miniconda3/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          AR           0.000000000000     0.000000000000    -1.803571428571    39.962383123700
#          AR           0.000000000000     0.000000000000     1.803571428571    39.962383123700
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.06484  C =      0.06484 [cm^-1]
#   Rotational constants: A = ************  B =   1943.87857  C =   1943.87857 [MHz]
#   Nuclear repulsion =   47.531640150477628
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 36
#   Nalpha       = 18
#   Nbeta        = 18
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 16
#     Number of basis functions: 36
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 444222 doubles for integral storage.
#   We computed 8270 shell quartets total.
#   Whereas there are 9316 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              357
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1.0845303305E-01.
#   Reciprocal condition number of the overlap matrix is 6.5624983176E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58423426093236   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59874722860422   -1.45130e-02   2.03460e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59919036483279   -4.43136e-04   5.12135e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59921567922493   -2.53144e-05   8.00838e-06 DIIS
#    @RHF iter   4: -1053.59921568435493   -5.13000e-09   7.88077e-07 DIIS
#    @RHF iter   5: -1053.59921568449272   -1.37788e-10   7.26639e-08 DIIS
#    @RHF iter   6: -1053.59921568449454   -1.81899e-12   1.06657e-08 DIIS
#    @RHF iter   7: -1053.59921568449431    2.27374e-13   1.50483e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118.605944     1Ag  -118.605944     2B1u  -12.317517
#        2Ag   -12.317509     3B1u   -9.566046     3Ag    -9.566042
#        1B2g   -9.566040     1B3g   -9.566040     1B3u   -9.566039
#        1B2u   -9.566039     4Ag    -1.275413     4B1u   -1.273210
#        5Ag    -0.597843     2B3u   -0.589281     2B2u   -0.589281
#        2B2g   -0.586557     2B3g   -0.586557     5B1u   -0.578095
#
#     Virtual:
#
#        6Ag     0.707996     3B3u    0.779465     3B2u    0.779465
#        3B2g    0.815609     3B3g    0.815609     6B1u    0.870602
#        7Ag     0.950032     7B1u    1.020383     8B1u    1.108420
#        1Au     1.108420     8Ag     1.108427     1B1g    1.108427
#        4B2u    1.108443     4B3u    1.108443     4B2g    1.108520
#        4B3g    1.108520     9Ag     1.109787     9B1u    1.116215
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NA   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NB   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#
#   @RHF Final Energy: -1053.59921568449431
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             47.5316401504776280
#     One-Electron Energy =               -1551.6229127048707142
#     Two-Electron Energy =                 450.4920568698986472
#     Total Energy =                      -1053.5992156844945384
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cs003.hpc.nyu.edu at Thu Nov  7 15:45:55 2024
# Module time:
# 	user time   =       1.27 seconds =       0.02 minutes
# 	system time =       0.08 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =     152.27 seconds =       2.54 minutes
# 	system time =      11.95 seconds =       0.20 minutes
# 	total time  =       2649 seconds =      44.15 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of SO shells:               8
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   9    1    4    4    1    9    4    4 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 28379 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Thu Nov  7 15:45:55 2024
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 36
# 	Number of active MOs = 36
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   9	    0	    5	    0	    4	    0
# 	 B1g	   1	    0	    0	    0	    1	    0
# 	 B2g	   4	    0	    2	    0	    2	    0
# 	 B3g	   4	    0	    2	    0	    2	    0
# 	 Au	   1	    0	    0	    0	    1	    0
# 	 B1u	   9	    0	    5	    0	    4	    0
# 	 B2u	   4	    0	    2	    0	    2	    0
# 	 B3u	   4	    0	    2	    0	    2	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.013 (MW) /      0.108 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.014 (MW) /      0.109 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 5 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 6 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.014 (MW) /      0.112 (MB)
#
# 	Nuclear Rep. energy          =     47.53164015047763
# 	SCF energy                   =  -1053.59921568449431
# 	One-electron energy          =  -1551.62291270042738
# 	Two-electron energy          =    450.49205686545446
# 	Reference energy             =  -1053.59921568449522
#
# *** tstop() called on cs003.hpc.nyu.edu at Thu Nov  7 15
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.291262538027391
#       * MP2 total energy                      = -1053.890996577719079
#
#     Opposite-spin CCSD correlation energy     =   -0.234684263006028
#     Same-spin CCSD correlation energy         =   -0.078063312721158
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.312747575727186
#       * CCSD total energy                     = -1053.912481615418756
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   34.290683251415999
#     SCF energy          (wfn)                = -1053.599734039687291
#     Reference energy    (file100)            = -1053.599734039691612
#     CCSD energy         (file100)            =   -0.312747575727186
#     Total CCSD energy   (file100)            = -1053.912481615418756
#
#     Number of ijk index combinations:             1140
#     Memory available in words               :        62500000
#     Approx. words needed per explicit thread:             256
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002598483859937
#       * CCSD(T) total energy                  = -1053.915080099278839
#
# Plot saved successfully.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 使用生成的文件 psi4_results.txt
data_file = "psi4_results.txt"

# 读取数据
data = np.loadtxt(data_file, skiprows=1)
Rvals = data[:, 0]  # 距离列
energies = data[:, 1]  # 能量列（Hartree）

# 将能量从 Hartree 转换为 kcal/mol (1 Hartree = 627.5095 kcal/mol)
hartree_to_kcalmol = 627.5095
energies = energies * hartree_to_kcalmol

# 转换为相对能量，以最小能量为基准
energies_relative = energies - np.min(energies)

# 使用多项式拟合
degree = 8  # 多项式的阶数，可根据需要调整
coefficients = np.polyfit(Rvals, energies_relative, degree)
poly_fit = np.poly1d(coefficients)

# 使用拟合的多项式计算拟合曲线
fitted_energies = poly_fit(Rvals)

# 绘制原始数据点和多项式拟合曲线
plt.figure(figsize=(8, 5))
plt.plot(Rvals, energies_relative, 'o', label="Calculated Relative Energies")
plt.plot(Rvals, fitted_energies, '-', label=f"Polynomial Fit (degree {degree})")
plt.xlabel("Distance (Å)")
plt.ylabel("Relative Energy (kcal/mol)")

# 自动确定 y 轴的范围，以适应相对能量
y_min = min(min(energies_relative), min(fitted_energies)) * 0.9  # 扩展 10%
y_max = max(max(energies_relative), max(fitted_energies)) * 1.1  # 扩展 10%
plt.ylim(y_min, y_max)  # 根据数据动态设置 y 轴范围

plt.legend()
plt.title("Fit of Relative Energies")

# 保存拟合图像
plt.savefig("/scratch/hz3883/Week10-IntroElectronicStructure/Polynomial_Fit_Relative_Energies.png")
print("Fitted plot saved successfully.")

plt.show()
# Out:
# Fitted plot saved successfully.

# %%
import numpy as np
import psi4
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# 设置内存
psi4.set_memory('500 MB')

# 定义距离范围并增加点
Rvals = np.linspace(3.5, 5.0, 15)  # 缩小距离范围，生成 15 个点
energies = []

# 计算每个距离的能量并保存到文件
with open("/scratch/hz3883/Week10-IntroElectronicStructure/psi4_results.txt", "w") as f:
    f.write("Distance(Å) Energy(Hartree)\n")
    for R in Rvals:
        # 定义氩分子的几何结构
        ar2 = psi4.geometry(f"""
        0 1
        Ar
        --
        Ar 1 {R}
        """)
        
        # 计算能量
        try:
            energy = psi4.energy('ccsd(t)/cc-pvdz', molecule=ar2)
            energies.append(energy)
            f.write(f"{R:.2f} {energy}\n")  # 保存距离和能量到文件
            print(f"Distance: {R} Å, Energy: {energy} Hartree")
        except Exception as e:
            print(f"Energy calculation failed at distance {R} Å with error: {e}")
            energies.append(np.nan)  # 若计算失败，存储 NaN 以占位

# 读取文件中的数据
data = np.loadtxt("/scratch/hz3883/Week10-IntroElectronicStructure/psi4_results.txt", skiprows=1)
Rvals = data[:, 0]
energies = data[:, 1]

# 将能量从 Hartree 转换为 kcal/mol
energies_kcalmol = energies * psi4.constants.hartree2kcalmol
print("Converted Energies (kcal/mol):", energies_kcalmol)

# Lennard-Jones 势函数定义
def lj_potential(R, sigma, epsilon):
    """Lennard-Jones potential function."""
    return 4 * epsilon * ((sigma / R)**12 - (sigma / R)**6)

# 对计算得到的数据进行拟合
params, _ = curve_fit(lj_potential, Rvals, energies_kcalmol, p0=[3.8, -0.2])
sigma_fit, eps_fit = params
print(f"Fitted parameters: σ = {sigma_fit:.3f} Å, ε = {eps_fit:.3f} kcal/mol")

# 生成拟合曲线的数据
R_fine = np.linspace(3.5, 5.0, 100)
E_fitted = lj_potential(R_fine, sigma_fit, eps_fit)

# 绘制计算点和拟合曲线
plt.figure(figsize=(8, 6))
plt.scatter(Rvals, energies_kcalmol, color='red', label='Data', zorder=5)
plt.plot(R_fine, E_fitted, color='blue', label=f"Fitted LJ potential\n($\\sigma$={sigma_fit:.3f}, $\\epsilon$={eps_fit:.3f})")
plt.xlabel('Interatomic Distance R (Å)')
plt.ylabel('Interaction Energy E (kcal/mol)')
plt.title('Counterpoise-Corrected Interaction Energy vs Distance')
plt.legend()
plt.grid(True)
plt.show()
params, _ = curve_fit(
    lj_potential, 
    Rvals, 
    energies_kcalmol, 
    p0=[3.8, -0.2], 
    maxfev=2000  # 增加 maxfev 到 2000
)

# 保存图表为 PNG 文件
plt.savefig('/scratch/hz3883/Week10-IntroElectronicStructure/Counterpoise_Corrected_Energy_vs_Distance.png')
print("Plot saved successfully.")

# 打印 CP 校正的相互作用能量
print("\nCP-corrected CCSD(T)/aug-cc-pVDZ Interaction Energies\n")
print("          R [Ang]                 E_int [kcal/mol]       ")
print("---------------------------------------------------------")
for i, R in enumerate(Rvals):
    e = energies_kcalmol[i]
    print(f"            {R:3.1f}                        {e:1.6f}")
# Out:
#   Memory set to 476.837 MiB by Python driver.
#
# Scratch directory: /tmp/
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Fri Nov  8 15:57:57 2024
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry AR         line   718 file /ext3/miniconda3/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          AR           0.000000000000     0.000000000000    -1.750000000000    39.962383123700
#          AR           0.000000000000     0.000000000000     1.750000000000    39.962383123700
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.06887  C =      0.06887 [cm^-1]
#   Rotational constants: A = ************  B =   2064.71317  C =   2064.71317 [MHz]
#   Nuclear repulsion =   48.986690359165706
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 36
#   Nalpha       = 18
#   Nbeta        = 18
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 16
#     Number of basis functions: 36
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 444222 doubles for integral storage.
#   We computed 8414 shell quartets total.
#   Whereas there are 9316 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              357
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1.0776133932E-01.
#   Reciprocal condition number of the overlap matrix is 6.4907846686E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58492467671863   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59842721774999   -1.35025e-02   2.04106e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59887230632285   -4.45089e-04   5.12417e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59889763542878   -2.53291e-05   8.71174e-06 DIIS
#    @RHF iter   4: -1053.59889764335435   -7.92556e-09   1.31985e-06 DIIS
#    @RHF iter   5: -1053.59889764375066   -3.96312e-10   8.60782e-08 DIIS
#    @RHF iter   6: -1053.59889764375134   -6.82121e-13   1.63414e-08 DIIS
#    @RHF iter   7: -1053.59889764375203   -6.82121e-13   2.40865e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#              12  11         0.0013411938
#               3   1        -0.0013334871
#              13  11         0.0009492970
#              14  14         0.0006546160
#              16  16         0.0006546160
#               2   0         0.0006539330
#               5   5         0.0006454715
#               7   7         0.0006454715
#              12  10         0.0006382154
#               4   1         0.0005719656
#
#     Largest TIjAb Amplitudes:
#      13  13   3   3        -0.0216511273
#       4   4   3   3        -0.0214345526
#      13  13  13  13        -0.0200762903
#       4  13   3  13        -0.0197591063
#      13   4  13   3        -0.0197591063
#      13  13   0   0        -0.0194276455
#       4   4   0   0        -0.0190863943
#       4  13  13   3        -0.0187750196
#      13   4   3  13        -0.0187750196
#       4   4  13  13        -0.0179864785
#
#     SCF energy       (wfn)                    = -1053.598897643752025
#     Reference energy (file100)                = -1053.598897643753844
#
#     Opposite-spin MP2 correlation energy      =   -0.210906447537580
#     Same-spin MP2 correlation energy          =   -0.080782052044888
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.291688499582468
#       * MP2 total energy                      = -1053.890586143336350
#
#     Opposite-spin CCSD correlation energy     =   -0.234863537008383
#     Same-spin CCSD correlation energy         =   -0.078227420895420
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.313090957903803
#       * CCSD total energy                     = -1053.911988601657640
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   48.986690359165706
#     SCF energy          (wfn)                = -1053.598897643752025
#     Reference energy    (file100)            = -1053.598897643753844
#     CCSD energy         (file100)            =   -0.313090957903803
#     Total CCSD energy   (file100)            = -1053.911988601657640
#
#     Number of ijk index combinations:             1140
#     Memory available in words               :        62500000
#     Approx. words needed per explicit thread:             256
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002626247532241
#       * CCSD(T) total energy                  = -1053.914614849189775
#
# Distance: 3.5 Å, Energy: -1053.9146148491898 Hartree
#
# Scratch directory: /tmp/
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Fri Nov  8 15:58:00 2024
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry AR         line   718 file /ext3/miniconda3/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          AR           0.000000000000     0.000000000000    -1.803571428571    39.962383123700
#          AR           0.000000000000     0.000000000000     1.803571428571    39.962383123700
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.06484  C =      0.06484 [cm^-1]
#   Rotational constants: A = ************  B =   1943.87857  C =   1943.87857 [MHz]
#   Nuclear repulsion =   47.531640150477628
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 36
#   Nalpha       = 18
#   Nbeta        = 18
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 16
#     Number of basis functions: 36
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 444222 doubles for integral storage.
#   We computed 8270 shell quartets total.
#   Whereas there are 9316 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              357
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1.0845303305E-01.
#   Reciprocal condition number of the overlap matrix is 6.5624983176E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58423426093236   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59874722860422   -1.45130e-02   2.03460e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59919036483234   -4.43136e-04   5.12135e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59921567922424   -2.53144e-05   8.00838e-06 DIIS
#    @RHF iter   4: -1053.59921568435516   -5.13091e-09   7.88077e-07 DIIS
#    @RHF iter   5: -1053.59921568449317   -1.38016e-10   7.26639e-08 DIIS
#    @RHF iter   6: -1053.59921568449431   -1.13687e-12   1.06657e-08 DIIS
#    @RHF iter   7: -1053.59921568449477   -4.54747e-13   1.50483e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118.605944     1Ag  -118.605944     2B1u  -12.317517
#        2Ag   -12.317509     3B1u   -9.566046     3Ag    -9.566042
#        1B2g   -9.566040     1B3g   -9.566040     1B3u   -9.566039
#        1B2u   -9.566039     4Ag    -1.275413     4B1u   -1.273210
#        5Ag    -0.597843     2B3u   -0.589281     2B2u   -0.589281
#        2B2g   -0.586557     2B3g   -0.586557     5B1u   -0.578095
#
#     Virtual:
#
#        6Ag     0.707996     3B3u    0.779465     3B2u    0.779465
#        3B2g    0.815609     3B3g    0.815609     6B1u    0.870602
#        7Ag     0.950032     7B1u    1.020383     1Au     1.108420
#        8B1u    1.108420     8Ag     1.108427     1B1g    1.108427
#        4B2u    1.108443     4B3u    1.108443     4B3g    1.108520
#        4B2g    1.108520     9Ag     1.109787     9B1u    1.116215
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NA   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NB   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#
#   @RHF Final Energy: -1053.
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   47.531640150477628
#     SCF energy          (wfn)                = -1053.599215684494766
#     Reference energy    (file100)            = -1053.599215684495675
#     CCSD energy         (file100)            =   -0.313013317660467
#     Total CCSD energy   (file100)            = -1053.912229002156209
#
#     Number of ijk index combinations:             1140
#     Memory available in words               :        62500000
#     Approx. words needed per explicit thread:             256
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002620119571853
#       * CCSD(T) total energy                  = -1053.914849121727912
#
# Distance: 3.607142857142857 Å, Energy: -1053.914849121728 Hartree
#
# Scratch directory: /tmp/
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Fri Nov  8 15:58:02 2024
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry AR         line   718 file /ext3/miniconda3/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          AR           0.000000000000     0.000000000000    -1.857142857143    39.962383123700
#          AR           0.000000000000     0.000000000000     1.857142857143    39.962383123700
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.06115  C =      0.06115 [cm^-1]
#   Rotational constants: A = ************  B =   1833.34923  C =   1833.34923 [MHz]
#   Nuclear repulsion =   46.160535146136922
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 36
#   Nalpha       = 18
#   Nbeta        = 18
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 16
#     Number of basis functions: 36
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 444222 doubles for integral storage.
#   We computed 8074 shell quartets total.
#   Whereas there are 9316 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              357
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 1.0895591635E-01.
#   Reciprocal condition number of the overlap matrix is 6.6181306286E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58379656340708   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59895700291577   -1.51604e-02   2.03038e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59939892991929   -4.41927e-04   5.11933e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59942424089900   -2.53110e-05   7.78935e-06 DIIS
#    @RHF iter   4: -1053.59942424516908   -4.27008e-09   4.49175e-07 DIIS
#    @RHF iter   5: -1053.59942424521159   -4.25189e-11   6.71868e-08 DIIS
#    @RHF iter   6: -1053.59942424521228   -6.82121e-13   6.45019e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118.606081     1Ag  -118.606081     2B1u  -12.317629
#        2Ag   -12.317623     3B1u   -9.566159     3Ag    -9.566155
#        1B2g   -9.566154     1B3g   -9.566154     1B2u   -9.566153
#        1B3u   -9.566153     4Ag    -1.275168     4B1u   -1.273518
#        5Ag    -0.596059     2B2u   -0.589029     2B3u   -0.589029
#        2B3g   -0.586894     2B2g   -0.586894     5B1u   -0.579911
#
#     Virtual:
#
#        6Ag     0.714324     3B2u    0.782437     3B3u    0.782437
#        3B3g    0.812411     3B2g    0.812411     6B1u    0.869650
#        7Ag     0.951522     7B1u    1.005738     8B1u    1.108375
#        1Au     1.108375     1B1g    1.108380     8Ag     1.108380
#        4B3u    1.108392     4B2u    1.108392     4B2g    1.108426
#        4B3g    1.108426     9Ag     1.109224     9B1u    1.112176
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NA   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NB   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#
#   @RHF Final Energy: -1053.59942424521228
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             46.1605351461369224
#     One-Electron Energy =               -1548.8782331765000890
#     Two-Electron Energy =                 449.1182737851509046
#     Total Energy =                      -1053.5994242452122762
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000           -0.0000000           -0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cs003.hpc.nyu.edu at Fri Nov  8 15:58:04 2024
# Module time:
# 	user time   =       1.18 seconds =       0.02 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =     195.44 seconds =       3.26 minutes
# 	system time =      16.51 seconds =       0.28 minutes
# 	total time  =      89778 seconds =    1496.30 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of SO shells:               8
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   9    1    4    4    1    9    4    4 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 28379 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Fri Nov  8 15:58:04 2024
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 36
# 	Number of active MOs = 36
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   9	    0	    5	    0	    4	    0
# 	 B1g	   1	    0	    0	    0	    1	    0
# 	 B2g	   4	    0	    2	    0	    2	    0
# 	 B3g	   4	    0	    2	    0	    2	    0
# 	 Au	   1	    0	    0	    0	    1	    0
# 	 B1u	   9	    0	    5	    0	    4	    0
# 	 B2u	   4	    0	    2	    0	    2	    0
# 	 B3u	   4	    0	    2	    0	    2	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.013 (MW) /      0.108 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.014 (MW) /      0.109 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# ...
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag         9       9
#      B1g        1       1
#      B2g        4       4
#      B3g        4       4
#      Au         1       1
#      B1u        9       9
#      B2u        4       4
#      B3u        4       4
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD: -1053.58309446227031   -1.05358e+03   0.00000e+00
#    @RHF iter   1: -1053.59926980747332   -1.61753e-02   2.02334e-03 DIIS/ADIIS
#    @RHF iter   2: -1053.59970873936641   -4.38932e-04   5.11119e-04 DIIS/ADIIS
#    @RHF iter   3: -1053.59973403634535   -2.52970e-05   7.38949e-06 DIIS
#    @RHF iter   4: -1053.59973403968684   -3.34148e-09   6.84057e-08 DIIS
#    @RHF iter   5: -1053.59973403968706   -2.27374e-13   8.44658e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u -118.606340     1Ag  -118.606340     2B1u  -12.317829
#        2Ag   -12.317829     3B1u   -9.566361     1B2g   -9.566361
#        1B3g   -9.566361     1B3u   -9.566361     1B2u   -9.566361
#        3Ag    -9.566360     4Ag    -1.274421     4B1u   -1.274390
#        5Ag    -0.588606     2B3u   -0.588080     2B2u   -0.588080
#        2B2g   -0.587994     2B3g   -0.587994     5B1u   -0.587467
#
#     Virtual:
#
#        6Ag     0.787824     3B3u    0.796503     3B2u    0.796503
#        3B3g    0.797879     3B2g    0.797879     6B1u    0.806628
#        7Ag     0.959262     7B1u    0.959928     4B2g    1.108301
#        4B3g    1.108301     8B1u    1.108301     1Au     1.108301
#        1B1g    1.108302     8Ag     1.108302     9Ag     1.108302
#        4B3u    1.108302     4B2u    1.108302     9B1u    1.108302
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NA   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#     NB   [     5,    0,    2,    2,    0,    5,    2,    2 ]
#
#   @RHF Final Energy: -1053.59973403968706
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             34.2906832514159987
#     One-Electron Energy =               -1525.1337700794306329
#     Two-Electron Energy =                 437.2433527883276838
#     Total Energy =                      -1053.5997340396870641
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on cs003.hpc.nyu.edu at Fri Nov  8 15:58:31 2024
# Module time:
# 	user time   =       0.77 seconds =       0.01 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =     219.26 seconds =       3.65 minutes
# 	system time =      19.32 seconds =       0.32 minutes
# 	total time  =      89805 seconds =    1496.75 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              16
#       Number of SO shells:               8
#       Number of primitives:            100
#       Number of atomic orbitals:        38
#       Number of basis functions:        36
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [   9    1    4    4    1    9    4    4 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 28379 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on cs003.hpc.nyu.edu
# *** at Fri Nov  8 15:58:32 2024
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 36
# 	Number of active MOs = 36
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   9	    0	    5	    0	    4	    0
# 	 B1g	   1	    0	    0	    0	    1	    0
# 	 B2g	   4	    0	    2	    0	    2	    0
# 	 B3g	   4	    0	    2	    0	    2	    0
# 	 Au	   1	    0	    0	    0	    1	    0
# 	 B1u	   9	    0	    5	    0	    4	    0
# 	 B2u	   4	    0	    2	    0	    2	    0
# 	 B3u	   4	    0	    2	    0	    2	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.001 (MW) /      0.008 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.003 (MW) /      0.020 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.013 (MW) /      0.108 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.001 (MW) /      0.007 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.003 (MW) /      0.022 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.014 (MW) /      0.109 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 4 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 5 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 6 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 7 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.014 (MW) /      0.112 (MB)
#
# 	Nuclear Rep. energy          =     34.29068325141600
# 	SCF energy                   =  -1053.59973403968706
# 	One-electron energy          =  -1525.13377036463226
# 	Two-electron energy          =    437.24335307352459
# 	Reference energy             =  -1053.59973403969161
#
# *** tstop() called on cs003.hpc.nyu.edu at Fri Nov  8 15:58:32 2024
# Module time:
# 	user time   =       0.03 seconds =       0.00 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =     219.97 seconds =       3.67 minutes
# 	system time =      19.36 seconds =       0.32 minutes
# 	total time  =      89806 seconds =    1496.77 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =   34.290683251415999
#     SCF energy          (wfn)     = -1053.599734039687064
#     Reference energy    (file100) = -1053.599734039691612
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     500.0
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
#     Using old T1 amplitudes.
#     Using old T2 amplitudes.
#
# MP2 correlation energy -0.2912625380273914
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.312747628379001    0.000e+00    0.000472    0.001484    0.001484    0.105561
#      1        -0.312747352844025    8.151e-04    0.000472    0.001487    0.001487    0.105534
#      2        -0.312747550876304    1.293e-04    0.000472    0.001484    0.001484    0.105533
#      3        -0.312747577471952    2.412e-05    0.000472    0.001483    0.001483    0.105531
#      4        -0.312747575613319    4.064e-06    0.000472    0.001483    0.001483    0.105531
#      5        -0.312747575553269    3.261e-07    0.000472    0.001483    0.001483    0.105531
#      6        -0.312747575727186    7.668e-08    0.000472    0.001483    0.001483    0.105531
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#              12  11         0.0014401713
#               3   1         0.0014385026
#               2   0         0.0006512428
#              14  14         0.0006493756
#              16  16         0.0006493756
#               5   5         0.0006490599
#               7   7         0.0006490599
#              11  10        -0.0006471149
#              13  10        -0.0004799266
#               6   5         0.0004299620
#
#     Largest TIjAb Amplitudes:
#      13  13  13  13        -0.0218206171
#       4  13   3  13         0.0217839673
#      13   4  13   3         0.0217839673
#       4   4   3   3        -0.0217473657
#      13  13   3   3        -0.0214723152
#       4  13  13   3         0.0214351510
#      13   4   3  13         0.0214351510
#       4   4  13  13        -0.0213980586
#      13  13   0   0        -0.0172944856
#       4   4   0   0        -0.0172690010
#
#     SCF energy       (wfn)                    = -1053.599734039687064
#     Reference energy (file100)                = -1053.599734039691612
#
#     Opposite-spin MP2 correlation energy      =   -0.210674295666566
#     Same-spin MP2 correlation energy          =   -0.080588242360825
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.291262538027391
#       * MP2 total energy                      = -1053.890996577719079
#
#     Opposite-spin CCSD correlation energy     =   -0.234684263006028
#     Same-spin CCSD correlation energy         =   -0.078063312721158
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.312747575727186
#       * CCSD total energy                     = -1053.912481615418756
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   34.290683251415999
#     SCF energy          (wfn)                = -1053.599734039687064
#     Reference energy    (file100)            = -1053.599734039691612
#     CCSD energy         (file100)            =   -0.312747575727186
#     Total CCSD energy   (file100)            = -1053.912481615418756
#
#     Number of ijk index combinations:             1140
#     Memory available in words               :        62500000
#     Approx. words needed per explicit thread:             256
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002598483859937
#       * CCSD(T) total energy                  = -1053.915080099278839
#
# Distance: 5.0 Å, Energy: -1053.9150800992788 Hartree
# Converted Energies (kcal/mol): [-661341.40537047 -661341.55237871 -661341.64228226 -661341.6945653
#  -661341.72235705 -661341.73456369 -661341.73724256 -661341.73448612
#  -661341.72900247 -661341.7225146  -661341.71604716 -661341.71014856
#  -661341.70505097 -661341.70079754 -661341.69731931]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [69], line 50
#      47     return 4 * epsilon * ((sigma / R)**12 - (sigma / R)**6)
#      49 # 对计算得到的数据进行拟合
# ---> 50 params, _ = curve_fit(lj_potential, Rvals, energies_kcalmol, p0=[3.8, -0.2])
#      51 sigma_fit, eps_fit = params
#      52 print(f"Fitted parameters: σ = {sigma_fit:.3f} Å, ε = {eps_fit:.3f} kcal/mol")
#
# File /ext3/miniconda3/lib//python3.9/site-packages/scipy/optimize/_minpack_py.py:839, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     837     cost = np.sum(infodict['fvec'] ** 2)
#     838     if ier not in [1, 2, 3, 4]:
# --> 839         raise RuntimeError("Optimal parameters not found: " + errmsg)
#     840 else:
#     841     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#     842     if 'max_nfev' not in kwargs:
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 600.
